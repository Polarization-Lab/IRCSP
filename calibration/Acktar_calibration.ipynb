# %%
import numpy as np
import pandas as pd
import h5py
import sys
import matplotlib.pyplot as plt
from statistics import mean
import scipy
from pathlib import Path

# %%
path = "/Users/kirahart/Desktop/BB_test/NUC_3hr_run1_BB50.h5"

# %%
a_file = h5py.File(path, "r")
print(a_file.keys())
# Out:
# <KeysViewHDF5 ['imgs1', 'imgs2', 'standev1', 'standev2', 'temps1', 'temps2']>

# %%
with h5py.File(path, 'r') as f:
    imgs1 = np.array(f['imgs1'])
    imgs2 = np.array(f['imgs2'])

# %%
plt.imshow(imgs1[20,100:200])
plt.show()

# %%
plt.plot(np.mean(imgs1[:,150,50:100],axis = 1),label = "acktar 1")
plt.plot(np.mean(imgs1[:,150,175:200],axis = 1),label = "acktar 2")
plt.plot(np.mean(imgs1[:,150,125:150],axis = 1),label = 'active')
plt.ylim([21900,22100])
plt.legend()
plt.show()

# %%
acktar = np.mean(imgs1[:,150,50:100],axis = 1)
active= imgs1[:,150,125]

plt.plot(active-acktar)
plt.show()
