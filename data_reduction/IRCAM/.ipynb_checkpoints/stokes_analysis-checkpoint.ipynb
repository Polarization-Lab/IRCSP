# %%
import numpy as np
import pandas as pd
import h5py
import sys
import matplotlib.pyplot as plt
from statistics import mean
from scipy.optimize import curve_fit
import imageio
from pathlib import Path
import warnings

# %%
file_path = '/Volumes/KESU/IRCAM_data/tests/'
name = "hand2.h5"

# %%
hf = h5py.File(file_path+name, 'r')
imgs = np.array(hf['imgs'])
ts  = np.array(hf['temps'])
ans = np.array(hf['set_angels'])
dark = np.array(hf['dark'])

for i in range(len(imgs)):
    imgs[i] = imgs[i] - dark

imgs[imgs < 0] = 0

S0 = np.sum(imgs,axis = 0)/2
S1 = imgs[0]-imgs[2]
S2 = imgs[1]-imgs[3]


s1 = S1/S0
s2 = S2/S0

DOLP = 100*np.sqrt(S1**2+S2**2)/S0
AOLP = 180/ (2*np.pi*np.arctan2 (S2,S1))
# Out:
# <ipython-input-129-b5ba71b55297>:17: RuntimeWarning: invalid value encountered in true_divide
#   s1 = S1/S0
# <ipython-input-129-b5ba71b55297>:18: RuntimeWarning: invalid value encountered in true_divide
#   s2 = S2/S0
# <ipython-input-129-b5ba71b55297>:20: RuntimeWarning: invalid value encountered in true_divide
#   DOLP = 100*np.sqrt(S1**2+S2**2)/S0
# <ipython-input-129-b5ba71b55297>:21: RuntimeWarning: divide by zero encountered in true_divide
#   AOLP = 180/ (2*np.pi*np.arctan2 (S2,S1))

# %%
fig, (ax1, ax2, ax3,ax4) = plt.subplots(figsize=(16, 5), ncols=4)

# STOKES IMAGES
# color "mappable" object returned by ax1.imshow
pos1 = ax1.imshow(np.transpose(imgs[0]), cmap='Greys_r', interpolation='none')
fig.colorbar(pos1, ax=ax1,extend='both',label = "ADU")
ax1.set_title("$0$",fontsize = 20)
ax1.axis('off')
    
pos2 = ax2.imshow(np.transpose(imgs[1]), cmap='Greys_r', interpolation='none')
fig.colorbar(pos2, ax=ax2,extend='both')
ax2.set_title("$45$",fontsize = 20)
ax2.axis('off')

pos3 = ax3.imshow(np.transpose(imgs[2]), cmap='Greys_r', interpolation='none')
fig.colorbar(pos3, ax=ax3,extend='both')
ax3.set_title("$90$",fontsize = 20)
ax3.axis('off')

pos4 = ax4.imshow(np.transpose(imgs[3]), cmap='Greys_r', interpolation='none')
fig.colorbar(pos4, ax=ax4,extend='both')
ax4.set_title("$135$",fontsize = 20)
ax4.axis('off')


plt.show()

print(ts)
# Out:
# [36.5 36.5 36.5 36.5]

# %%
#set clim for S0 image
S0mean = np.mean(S0)
S0std  = np.std(S0)
dev = 3
    
s1m = np.max(np.abs(S1/S0))
s2m = np.max(np.abs(S2/S0)) 
    
#AOLP DOLP
fig, (ax2, ax3) = plt.subplots(figsize=(10, 5), ncols=2)
# plot just the positive data and save the
# color "mappable" object returned by ax1.imshow


pos2 = ax2.imshow(np.transpose(DOLP), cmap='Greys_r', interpolation='none',vmin=0, vmax=30)
fig.colorbar(pos2, ax=ax2,extend='both',label = '[%]')
ax2.set_title("DOLP",fontsize = 20)
ax2.axis('off')

pos3 = ax3.imshow(np.transpose(AOLP), cmap='hsv', interpolation='none',vmin=0, vmax=180)
fig.colorbar(pos3, ax=ax3,extend='both',label = "[$^\circ$]")
ax3.set_title("AOLP",fontsize = 20)
ax3.axis('off')
plt.show()
# Out:
# <ipython-input-131-d2bf2d20af57>:6: RuntimeWarning: invalid value encountered in true_divide
#   s1m = np.max(np.abs(S1/S0))
# <ipython-input-131-d2bf2d20af57>:7: RuntimeWarning: invalid value encountered in true_divide
#   s2m = np.max(np.abs(S2/S0))

# %%
fig, (ax1, ax2, ax3) = plt.subplots(figsize=(16, 5), ncols=3)

# STOKES IMAGES
# color "mappable" object returned by ax1.imshow
pos1 = ax1.imshow(np.transpose(S0), cmap='Greys_r', interpolation='none',vmin=S0mean - dev*S0std, vmax= S0mean + dev*S0std)
fig.colorbar(pos1, ax=ax1,extend='both',label = "ADU")
ax1.set_title("$S_0$",fontsize = 20)
ax1.axis('off')
    
pos2 = ax2.imshow(np.transpose(s1), cmap='bwr', interpolation='none',vmin = -s1m, vmax = s1m)
fig.colorbar(pos2, ax=ax2,extend='both')
ax2.set_title("$s_1$",fontsize = 20)
ax2.axis('off')

pos3 = ax3.imshow(np.transpose(s2), cmap='bwr', interpolation='none',vmin = -s2m, vmax = s2m)
fig.colorbar(pos3, ax=ax3,extend='both')
ax3.set_title("$s_2$",fontsize = 20)
ax3.axis('off')


plt.show()
