# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import matplotlib.patches as mpatches
import math
import matplotlib.lines as mlines
import matplotlib.pyplot as plt

# %%
with h5py.File('C:\\Users\\khart\\Documents\\IRCSP2_data\\Jaclyn\\P3\\IRCSP_Flight1\\images.h5', "r") as f:
    # List all groups
    print(f.keys())
    
    # Get the data
    imgs1 = np.array(f[list(f.keys())[0]])
    imgs2 = np.array(f[list(f.keys())[1]])
# Out:
# <KeysViewHDF5 ['img1', 'img2', 'temp1', 'temp2', 'time']>

# %%
np.shape(imgs1)
# Out:
# (163840,)

# %%
fig = plt.imshow(imgs1[0])
plt.title('Camera 1 Image: Unscrewed')
plt.colorbar()
fig.axes.get_xaxis().set_visible(False)
fig.axes.get_yaxis().set_visible(False)

# %%
fig = plt.imshow(imgs2[0])
plt.title('Camera 2 Image: Unscrewed')
plt.colorbar()
fig.axes.get_xaxis().set_visible(False)
fig.axes.get_yaxis().set_visible(False)

# %%
fig = plt.imshow(imgs3[0])
plt.title('Camera 1 Image: Screwed In')
plt.colorbar()
fig.axes.get_xaxis().set_visible(False)
fig.axes.get_yaxis().set_visible(False)

# %%
fig = plt.imshow(imgs4[0])
plt.title('Camera 2 Image: Screwed In')
plt.colorbar()
fig.axes.get_xaxis().set_visible(False)
fig.axes.get_yaxis().set_visible(False)

# %%
with h5py.File('C:\\Users\\khart\\Documents\\IRCSP2_data\\Jaclyn\\NUC_3hr_run1_BB30.h5', "r") as f:
    # List all groups
    print(f.keys())
    
    # Get the data
    run1imgs1 = np.array(f[list(f.keys())[0]])
    run1imgs2 = np.array(f[list(f.keys())[1]])
    run1std1 = np.array(f[list(f.keys())[2]])
    run1std2 = np.array(f[list(f.keys())[3]])
    run1temps1 = np.array(f[list(f.keys())[4]])
    run1temps2 = np.array(f[list(f.keys())[5]])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-77-3f5a48eb858d> in <module>
# ----> 1 with h5py.File('C:\\Users\\khart\\Documents\\IRCSP2_data\\Jaclyn\\NUC_3hr_run1_BB30.h5', "r") as f:
#       2     # List all groups
#       3     print(f.keys())
#       4
#       5     # Get the data
#
# ~\AppData\Local\Continuum\anaconda3\envs\IRCAM\lib\site-packages\h5py\_hl\files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, **kwds)
#     443                                fapl, fcpl=make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     444                                fs_persist=fs_persist, fs_threshold=fs_threshold),
# --> 445                                swmr=swmr)
#     446
#     447             if isinstance(libver, tuple):
#
# ...

# %%
with h5py.File('C:\\Users\\khart\\Documents\\IRCSP2_data\\Jaclyn\\NUC_3hr_run1_BB40.h5', "r") as f:
    # List all groups
    print(f.keys())
    
    # Get the data
    run2imgs1 = np.array(f[list(f.keys())[0]])
    run2imgs2 = np.array(f[list(f.keys())[1]])
    run2std1 = np.array(f[list(f.keys())[2]])
    run2std2 = np.array(f[list(f.keys())[3]])
    run2temps1 = np.array(f[list(f.keys())[4]])
    run2temps2 = np.array(f[list(f.keys())[5]])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-78-b858cdb3f659> in <module>
# ----> 1 with h5py.File('C:\\Users\\khart\\Documents\\IRCSP2_data\\Jaclyn\\NUC_3hr_run1_BB40.h5', "r") as f:
#       2     # List all groups
#       3     print(f.keys())
#       4
#       5     # Get the data
#
# ~\AppData\Local\Continuum\anaconda3\envs\IRCAM\lib\site-packages\h5py\_hl\files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, **kwds)
#     443                                fapl, fcpl=make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     444                                fs_persist=fs_persist, fs_threshold=fs_threshold),
# --> 445                                swmr=swmr)
#     446
#     447             if isinstance(libver, tuple):
#
# ...

# %%
with h5py.File('C:\\Users\\khart\\Documents\\IRCSP2_data\\Jaclyn\\NUC_3hr_run1_BB50.h5', "r") as f:
    # List all groups
    print(f.keys())
    
    # Get the data
    run3imgs1 = np.array(f[list(f.keys())[0]])
    run3imgs2 = np.array(f[list(f.keys())[1]])
    run3std1 = np.array(f[list(f.keys())[2]])
    run3std2 = np.array(f[list(f.keys())[3]])
    run3temps1 = np.array(f[list(f.keys())[4]])
    run3temps2 = np.array(f[list(f.keys())[5]])
# Out:
# <KeysViewHDF5 ['imgs1', 'imgs2', 'standev1', 'standev2', 'temps1', 'temps2']>

# %%
with h5py.File('C:\\Users\\khart\\Documents\\IRCSP2_data\\Jaclyn\\NUC_3hr_run2_BB50.h5', "r") as f:
    # List all groups
    print(f.keys())
    
    # Get the data
    run4imgs1 = np.array(f[list(f.keys())[0]])
    run4imgs2 = np.array(f[list(f.keys())[1]])
    run4std1 = np.array(f[list(f.keys())[2]])
    run4std2 = np.array(f[list(f.keys())[3]])
    run4temps1 = np.array(f[list(f.keys())[4]])
    run4temps2 = np.array(f[list(f.keys())[5]])
# Out:
# <KeysViewHDF5 ['imgs1', 'imgs2', 'standev1', 'standev2', 'temps1', 'temps2']>

# %%
y1 = []
for i in range(len(run1imgs1)):
    im = run1imgs1[i]
    y1.append(np.mean(im[120:170,110:160]))
    
y2 = []
for i in range(len(run1imgs1)):
    im = run1imgs1[i]
    y2.append(np.mean(im[170:220,110:160])) #below active region  50x50 pixel range

y3 = []
for i in range(len(run1imgs1)):
    im = run1imgs1[i]
    y3.append(np.mean(im[70:120,110:160]))#above active region  50x50 pixel range

# %%
error1 = []
for n in range(len(run1std1)): 
    er1 = np.mean((y1[n]-im[120:170,110:160])**2)
    er1 = er1/(len(y1)-1)
    error1.append(np.sqrt(er1))

# %%
np.shape(run3imgs1)
# Out:
# (360, 256, 320)

# %%
plt.imshow(run3imgs1[0])#[120:170,110:160])
plt.colorbar()
#plt.clim(21800,22300)
plt.title('Camera 1')
plt.show()


y1 = []
for i in range(len(run3imgs1)):
    im = run3imgs1[i]
    y1.append(np.mean(im[170:220,110:160]))

plt.plot(np.arange(0,180,.5),val)
plt.show()

# %%
slopes1 = []


n = 20
z1 = run1temps1[n:]
y1 = run1imgs1[n:]


for i in range(256):
    for j in range(320):
        fit = np.polyfit(z1,y1[:,i,j],1)
        slopes1.append(fit[0])

        
slopes1 = np.reshape(slopes1,[256,320])

# %%
plt.imshow(slopes1)
plt.colorbar()
#slopes1 is an array of all the response vs temp slopes at every pixel

# %%
# Out:
# -5.417737572956451

# %% [markdown]
# error1

# %%
fig, ax = plt.subplots()

n=20

x1 = np.arange(0,180,.5)
x1 = x1[n:]

y1 = []
for i in range(len(run1imgs1)):
    im = run1imgs1[i]
    y1.append(np.mean(im[120:170,110:160]))
    
y1 = y1[n:]
error1 = error1[n:]

z1 = run1temps1
z1=z1[n:]


colors = ['r','g','b','c','y','m','k']

for i in range(len(y1)):
    if z1[i]<=32:
        plt.errorbar(x1[i], y1[i], c=colors[0],marker='x',yerr=error1[i],fmt ='o')
    elif z1[i]<=33:
        plt.errorbar(x1[i], y1[i], c=colors[1],marker='x',yerr=error1[i],fmt ='o') 
    elif z1[i]<=34:
        plt.errorbar(x1[i], y1[i], c=colors[2],marker='x',yerr=error1[i],fmt ='o')
    elif z1[i]<=35:
        plt.errorbar(x1[i], y1[i], c=colors[3],marker='x',yerr=error1[i],fmt ='o')
    elif z1[i]<=36:
        plt.errorbar(x1[i], y1[i], c=colors[4],marker='x',yerr=error1[i],fmt ='o')
    elif z1[i]<=37:
        plt.errorbar(x1[i], y1[i], c=colors[5],marker='x',yerr=error1[i],fmt ='o')
    elif z1[i]<=38: 
        plt.errorbar(x1[i], y1[i], c=colors[6],marker='x',yerr=error1[i],fmt ='o')

        
ax.set_xlabel("time(min)") 
ax.set_ylabel("Average Response") 
plt.title('Camera 1')


plt.show()

# %%
fig, ax = plt.subplots()

n = 20 #cut out first ten minutes

x1 = np.arange(0,180,.5)
x1 = x1[n:]
z1 = run1temps1
z1 = z1[n:]


y1 = []
for i in range(len(run1imgs1)):
    im = run1imgs1[i]
    y1.append(np.mean(im[120:170,110:160])) #active region 50x50 pixel range
    
error1 = run1std1[:][125,125]

y2 = []
for i in range(len(run1imgs1)):
    im = run1imgs1[i]
    y2.append(np.mean(im[170:220,110:160])) #below active region  50x50 pixel range

error2 = run2std1[:][125,200]

y3 = []
for i in range(len(run1imgs1)):
    im = run1imgs1[i]
    y3.append(np.mean(im[70:120,110:160]))#above active region  50x50 pixel range
    
y1 = y1[n:]
y2 = y2[n:]
y3 = y3[n:]
    
error3 = run1std1[:][125,100]

colors = ['r','g','b','c','y','m','k']

for i in range(len(z1[n:])):
    if z1[i]<=32:
        plt.errorbar(x1[i], y1[i], c=colors[0],marker='x',yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i], y2[i], c=colors[0],marker = 'o',yerr=error2[i],fmt ='o')
        plt.errorbar(x1[i], y3[i], c=colors[0],marker = 'v',yerr=error3[i],fmt ='o')
    elif z1[i]<=33:
        plt.errorbar(x1[i], y1[i], c=colors[1],marker='x',yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i], y2[i], c=colors[1],marker = 'o',yerr=error2[i],fmt ='o')
        plt.errorbar(x1[i], y3[i], c=colors[1],marker = 'v',yerr=error3[i],fmt ='o')        
    elif z1[i]<=34:
        plt.errorbar(x1[i], y1[i],c=colors[2],marker='x',yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i], y2[i],c=colors[2],marker = 'o',yerr=error2[i],fmt ='o')
        plt.errorbar(x1[i], y3[i],c=colors[2],marker = 'v',yerr=error3[i],fmt ='o')
    elif z1[i]<=35:
        plt.errorbar(x1[i], y1[i],c=colors[3],marker='x', yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i], y2[i],c=colors[3], marker = 'o',yerr=error2[i],fmt ='o')
        plt.errorbar(x1[i], y3[i],c=colors[3], marker = 'v',yerr=error3[i],fmt ='o')
    elif z1[i]<=36:
        plt.errorbar(x1[i], y1[i], c=colors[4],marker='x',yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i], y2[i], c=colors[4],marker = 'o',yerr=error2[i],fmt ='o')
        plt.errorbar(x1[i], y3[i], c=colors[4],marker = 'v',yerr=error3[i],fmt ='o')
    elif z1[i]<=37:
        plt.errorbar(x1[i], y1[i],c=colors[5],marker='x',yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i], y2[i],c=colors[5], marker = 'o',yerr=error2[i],fmt ='o')
        plt.errorbar(x1[i], y3[i],c=colors[5], marker = 'v',yerr=error3[i],fmt ='o')
    elif z1[i]<=38: 
        plt.errorbar(x1[i],y1[i],c=colors[6],marker='x',yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i],y2[i],c=colors[6],marker = 'o',yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i],y3[i],c=colors[6],marker = 'v',yerr=error3[i],fmt ='o')

        
        
ax.set_xlabel("time(min)") 
ax.set_ylabel("Average Response") 
plt.title('Camera 1, BB30C')


plt.show()

fit1 = np.polyfit(z1,y1,1) #slope of response vs temp temperature in the three regions
print('slope1 =',fit1[0])
print('intercept1 = ', fit1[1])

fit2 = np.polyfit(z1,y2,1)
print('slope2 =',fit2[0])
print('intercept2 = ', fit2[1])

fit3 = np.polyfit(z1,y3,1)
print('slope3 =',fit3[0])
print('intercept3 = ', fit3[1])
# Out:
# slope1 = -14.523632156685096
# intercept1 =  22309.568932463782
# slope2 = -9.415651309015276
# intercept2 =  22063.73597726744
# slope3 = -13.722850913141937
# intercept3 =  22388.27555450018

# %%
fig, ax = plt.subplots()

n = 20 #cut out first ten minutes

x1 = np.arange(0,180,.5)
x1 = x1[n:]
z1 = run2temps1
z1 = z1[n:]


y1 = []
for i in range(len(run2imgs1)):
    im = run2imgs1[i]
    y1.append(np.mean(im[120:170,110:160])) #active region 50x50 pixel range
    
error1 = run1std1[:][125,125]

y2 = []
for i in range(len(run2imgs1)):
    im = run2imgs1[i]
    y2.append(np.mean(im[170:220,110:160])) #below active region  50x50 pixel range

error2 = run2std1[:][125,200]

y3 = []
for i in range(len(run2imgs1)):
    im = run2imgs1[i]
    y3.append(np.mean(im[70:120,110:160]))#above active region  50x50 pixel range
    
y1 = y1[n:]
y2 = y2[n:]
y3 = y3[n:]
    
error3 = run2std1[:][125,100]

colors = ['r','g','b','c','y','m','k']

for i in range(len(z1[n:])):
    if z1[i]<=32:
        plt.errorbar(x1[i], y1[i], c=colors[0],marker='x',yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i], y2[i], c=colors[0],marker = 'o',yerr=error2[i],fmt ='o')
        plt.errorbar(x1[i], y3[i], c=colors[0],marker = 'v',yerr=error3[i],fmt ='o')
    elif z1[i]<=33:
        plt.errorbar(x1[i], y1[i], c=colors[1],marker='x',yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i], y2[i], c=colors[1],marker = 'o',yerr=error2[i],fmt ='o')
        plt.errorbar(x1[i], y3[i], c=colors[1],marker = 'v',yerr=error3[i],fmt ='o')        
    elif z1[i]<=34:
        plt.errorbar(x1[i], y1[i],c=colors[2],marker='x',yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i], y2[i],c=colors[2],marker = 'o',yerr=error2[i],fmt ='o')
        plt.errorbar(x1[i], y3[i],c=colors[2],marker = 'v',yerr=error3[i],fmt ='o')
    elif z1[i]<=35:
        plt.errorbar(x1[i], y1[i],c=colors[3],marker='x', yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i], y2[i],c=colors[3], marker = 'o',yerr=error2[i],fmt ='o')
        plt.errorbar(x1[i], y3[i],c=colors[3], marker = 'v',yerr=error3[i],fmt ='o')
    elif z1[i]<=36:
        plt.errorbar(x1[i], y1[i], c=colors[4],marker='x',yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i], y2[i], c=colors[4],marker = 'o',yerr=error2[i],fmt ='o')
        plt.errorbar(x1[i], y3[i], c=colors[4],marker = 'v',yerr=error3[i],fmt ='o')
    elif z1[i]<=37:
        plt.errorbar(x1[i], y1[i],c=colors[5],marker='x',yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i], y2[i],c=colors[5], marker = 'o',yerr=error2[i],fmt ='o')
        plt.errorbar(x1[i], y3[i],c=colors[5], marker = 'v',yerr=error3[i],fmt ='o')
    elif z1[i]<=38: 
        plt.errorbar(x1[i],y1[i],c=colors[6],marker='x',yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i],y2[i],c=colors[6],marker = 'o',yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i],y3[i],c=colors[6],marker = 'v',yerr=error3[i],fmt ='o')

        
        
ax.set_xlabel("time(min)") 
ax.set_ylabel("Average Response") 
plt.title('Camera 1, BB40C')


plt.show()

fit1 = np.polyfit(z1,y1,1) #slope of response vs temp temperature in the three regions
print('slope1 =',fit1[0])
print('intercept1 = ', fit1[1])

fit2 = np.polyfit(z1,y2,1)
print('slope2 =',fit2[0])
print('intercept2 = ', fit2[1])

fit3 = np.polyfit(z1,y3,1)
print('slope3 =',fit3[0])
print('intercept3 = ', fit3[1])
# Out:
# slope1 = -18.65355035142993
# intercept1 =  22565.178682235975
# slope2 = -15.420295357681043
# intercept2 =  22365.27198006752
# slope3 = -17.575904579478543
# intercept3 =  22614.63903420819

# %%
fig, ax = plt.subplots()

n = 20 #cut out first ten minutes

x1 = np.arange(0,180,.5)
x1 = x1[n:]
z1 = run3temps1
z1 = z1[n:]


y1 = []
for i in range(len(run3imgs1)):
    im = run3imgs1[i]
    y1.append(np.mean(im[120:170,110:160])) #active region 50x50 pixel range
    
error1 = run3std1[:][125,125]

y2 = []
for i in range(len(run3imgs1)):
    im = run3imgs1[i]
    y2.append(np.mean(im[170:220,110:160])) #below active region  50x50 pixel range

error2 = run3std1[:][125,200]

y3 = []
for i in range(len(run3imgs1)):
    im = run3imgs1[i]
    y3.append(np.mean(im[70:120,110:160]))#above active region  50x50 pixel range
    
y1 = y1[n:]
y2 = y2[n:]
y3 = y3[n:]
    
error3 = run3std1[:][125,100]

colors = ['r','g','b','c','y','m','k']

for i in range(len(z1[n:])):
    if z1[i]<=32:
        plt.errorbar(x1[i], y1[i], c=colors[0],marker='x',yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i], y2[i], c=colors[0],marker = 'o',yerr=error2[i],fmt ='o')
        plt.errorbar(x1[i], y3[i], c=colors[0],marker = 'v',yerr=error3[i],fmt ='o')
    elif z1[i]<=33:
        plt.errorbar(x1[i], y1[i], c=colors[1],marker='x',yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i], y2[i], c=colors[1],marker = 'o',yerr=error2[i],fmt ='o')
        plt.errorbar(x1[i], y3[i], c=colors[1],marker = 'v',yerr=error3[i],fmt ='o')        
    elif z1[i]<=34:
        plt.errorbar(x1[i], y1[i],c=colors[2],marker='x',yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i], y2[i],c=colors[2],marker = 'o',yerr=error2[i],fmt ='o')
        plt.errorbar(x1[i], y3[i],c=colors[2],marker = 'v',yerr=error3[i],fmt ='o')
    elif z1[i]<=35:
        plt.errorbar(x1[i], y1[i],c=colors[3],marker='x', yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i], y2[i],c=colors[3], marker = 'o',yerr=error2[i],fmt ='o')
        plt.errorbar(x1[i], y3[i],c=colors[3], marker = 'v',yerr=error3[i],fmt ='o')
    elif z1[i]<=36:
        plt.errorbar(x1[i], y1[i], c=colors[4],marker='x',yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i], y2[i], c=colors[4],marker = 'o',yerr=error2[i],fmt ='o')
        plt.errorbar(x1[i], y3[i], c=colors[4],marker = 'v',yerr=error3[i],fmt ='o')
    elif z1[i]<=37:
        plt.errorbar(x1[i], y1[i],c=colors[5],marker='x',yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i], y2[i],c=colors[5], marker = 'o',yerr=error2[i],fmt ='o')
        plt.errorbar(x1[i], y3[i],c=colors[5], marker = 'v',yerr=error3[i],fmt ='o')
    elif z1[i]<=38: 
        plt.errorbar(x1[i],y1[i],c=colors[6],marker='x',yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i],y2[i],c=colors[6],marker = 'o',yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i],y3[i],c=colors[6],marker = 'v',yerr=error3[i],fmt ='o')

        
        
ax.set_xlabel("time(min)") 
ax.set_ylabel("Average Response") 
plt.title('Camera 1, BB50C')


plt.show()

fit1 = np.polyfit(z1,y1,1) #slope of response vs temp temperature in the three regions
print('slope1 =',fit1[0])
print('intercept1 = ', fit1[1])

fit2 = np.polyfit(z1,y2,1)
print('slope2 =',fit2[0])
print('intercept2 = ', fit2[1])

fit3 = np.polyfit(z1,y3,1)
print('slope3 =',fit3[0])
print('intercept3 = ', fit3[1])
# Out:
# slope1 = -9.1174235291024
# intercept1 =  22324.91491905115
# slope2 = -5.8688494885226214
# intercept2 =  22098.734179129584
# slope3 = -8.135507038685374
# intercept3 =  22357.892769970134

# %%
fig, ax = plt.subplots()

n = 20 #cut out first ten minutes

x1 = np.arange(0,180,.5)
x1 = x1[n:]
z1 = run4temps1
z1 = z1[n:]


y1 = []
for i in range(len(run4imgs1)):
    im = run4imgs1[i]
    y1.append(np.mean(im[120:170,110:160])) #active region 50x50 pixel range
    
error1 = run4std1[:][125,125]

y2 = []
for i in range(len(run4imgs1)):
    im = run4imgs1[i]
    y2.append(np.mean(im[170:220,110:160])) #below active region  50x50 pixel range

error2 = run4std1[:][125,200]

y3 = []
for i in range(len(run4imgs1)):
    im = run4imgs1[i]
    y3.append(np.mean(im[70:120,110:160]))#above active region  50x50 pixel range
    
y1 = y1[n:]
y2 = y2[n:]
y3 = y3[n:]
    
error3 = run3std1[:][125,100]

colors = ['r','g','b','c','y','m','k']

for i in range(len(z1[n:])):
    if z1[i]<=32:
        plt.errorbar(x1[i], y1[i], c=colors[0],marker='x',yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i], y2[i], c=colors[0],marker = 'o',yerr=error2[i],fmt ='o')
        plt.errorbar(x1[i], y3[i], c=colors[0],marker = 'v',yerr=error3[i],fmt ='o')
    elif z1[i]<=33:
        plt.errorbar(x1[i], y1[i], c=colors[1],marker='x',yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i], y2[i], c=colors[1],marker = 'o',yerr=error2[i],fmt ='o')
        plt.errorbar(x1[i], y3[i], c=colors[1],marker = 'v',yerr=error3[i],fmt ='o')        
    elif z1[i]<=34:
        plt.errorbar(x1[i], y1[i],c=colors[2],marker='x',yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i], y2[i],c=colors[2],marker = 'o',yerr=error2[i],fmt ='o')
        plt.errorbar(x1[i], y3[i],c=colors[2],marker = 'v',yerr=error3[i],fmt ='o')
    elif z1[i]<=35:
        plt.errorbar(x1[i], y1[i],c=colors[3],marker='x', yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i], y2[i],c=colors[3], marker = 'o',yerr=error2[i],fmt ='o')
        plt.errorbar(x1[i], y3[i],c=colors[3], marker = 'v',yerr=error3[i],fmt ='o')
    elif z1[i]<=36:
        plt.errorbar(x1[i], y1[i], c=colors[4],marker='x',yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i], y2[i], c=colors[4],marker = 'o',yerr=error2[i],fmt ='o')
        plt.errorbar(x1[i], y3[i], c=colors[4],marker = 'v',yerr=error3[i],fmt ='o')
    elif z1[i]<=37:
        plt.errorbar(x1[i], y1[i],c=colors[5],marker='x',yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i], y2[i],c=colors[5], marker = 'o',yerr=error2[i],fmt ='o')
        plt.errorbar(x1[i], y3[i],c=colors[5], marker = 'v',yerr=error3[i],fmt ='o')
    elif z1[i]<=38: 
        plt.errorbar(x1[i],y1[i],c=colors[6],marker='x',yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i],y2[i],c=colors[6],marker = 'o',yerr=error1[i],fmt ='o')
        plt.errorbar(x1[i],y3[i],c=colors[6],marker = 'v',yerr=error3[i],fmt ='o')

        
        
ax.set_xlabel("time(min)") 
ax.set_ylabel("Average Response") 
plt.title('Camera 1, BB50C')


plt.show()

# %%
patch0 = mpatches.Patch(color=colors[0], label='<=32C')
patch1 = mpatches.Patch(color=colors[1], label='<=33C')
patch2 = mpatches.Patch(color=colors[2], label='<=34C')
patch3 = mpatches.Patch(color=colors[3], label='<=35C')
patch4 = mpatches.Patch(color=colors[4], label='<=36C')
patch5 = mpatches.Patch(color=colors[5], label='<=37C')
patch6 = mpatches.Patch(color=colors[6], label='<=38C')


plt.legend(handles=[patch0, patch1,patch2,patch3,patch4,patch5,patch6])

# %%
blue_star = mlines.Line2D([], [], marker='x', linestyle='None',
                          markersize=10,color = 'black', label='Active Region')
red_square = mlines.Line2D([], [], marker='o', linestyle='None',
                          markersize=10,color = 'black',label='Below Active Region')
purple_triangle = mlines.Line2D([], [], marker='^', linestyle='None',
                          markersize=10,color = 'black', label='Above Active Region')

plt.legend(handles=[blue_star, red_square, purple_triangle])

# %%
fig, ax = plt.subplots()

n=20

y1 = []
for i in range(len(run3imgs1)):
    im = run3imgs1[i]
    y1.append(np.mean(im[120:170,110:160]))
    
z1 = run3temps1[n:]

plt.scatter(z1,y1[n:])

fit = np.polyfit(z1,y1[n:],1)
x = fit[0]*z1 + fit[1]
plt.plot(z1,x,'-r')
plt.title('Camera 1')

fit
# Out:
# array([-9.11742353e+00,  2.23249149e+04])

# %%
plt.imshow(im[120:170,110:160])
