# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import matplotlib.patches as mpatches
import math
import matplotlib.lines as mlines
import os
import cv2 as cv
from IPython.display import Video
import matplotlib.cm as cm
import matplotlib.animation as animation
import matplotlib.image as mpimg
from statistics import mean
from scipy.optimize import curve_fit
from matplotlib.pyplot import figure

# %%
img1 = np.zeros([1,256,320])
img2 = np.zeros([1,256,320])

with h5py.File('C://Users//khart//Documents//Summer2022Campaign//Troubleshooting//useful//Balloon//hot_iron_45degpolarized.h5', "r") as f:

    img1 = np.array(f[list(f.keys())[0]])
    img2 = np.array(f[list(f.keys())[1]])

# %%
plt.imshow(img1[0])
plt.colorbar()
plt.clim(22900,24000)
plt.title("Balloon Camera 1 Hot Iron Target Polarized 45deg")
# Out:
# Text(0.5, 1.0, 'Balloon Camera 1 Hot Iron Target Polarized 45deg')

# %%
plt.imshow(img2[0])
plt.colorbar()
plt.clim(22900,24000)
plt.title("Balloon Camera 2 Hot Iron Target Polarized 45deg")
# Out:
# Text(0.5, 1.0, 'Balloon Camera 2 Hot Iron Target Polarized 45deg')

# %%
img1 = np.zeros([1,256,320])
img2 = np.zeros([1,256,320])

with h5py.File('C://Users//khart//Documents//Summer2022Campaign//Troubleshooting//useful//Balloon//hot_iron_135degpolarized.h5', "r") as f:

    img1 = np.array(f[list(f.keys())[0]])
    img2 = np.array(f[list(f.keys())[1]])

# %%
plt.imshow(img1[0])
plt.colorbar()
plt.clim(22900,24000)
plt.title("Balloon Camera 1 Hot Iron Target Polarized 135deg")
# Out:
# Text(0.5, 1.0, 'Balloon Camera 1 Hot Iron Target Polarized 135deg')

# %%
plt.imshow(img2[0])
plt.colorbar()
plt.clim(22900,24000)
plt.title("Balloon Camera 2 Hot Iron Target Polarized 135deg")
# Out:
# Text(0.5, 1.0, 'Balloon Camera 2 Hot Iron Target Polarized 135deg')

# %%
img1 = np.zeros([1,256,320])
img2 = np.zeros([1,256,320])

with h5py.File('C://Users//khart//Documents//Summer2022Campaign//Troubleshooting//useful//Balloon//unpolarized.h5', "r") as f:

    img1 = np.array(f[list(f.keys())[0]])
    img2 = np.array(f[list(f.keys())[1]])

# %%
plt.imshow(img1[0])
plt.colorbar()
plt.clim(22900,24000)
plt.title("Balloon Camera 1 Hot Iron Target Unpolarized")
# Out:
# Text(0.5, 1.0, 'Balloon Camera 1 Hot Iron Target Unpolarized')

# %%
plt.imshow(img2[0])
plt.colorbar()
plt.clim(22900,24000)
plt.title("Balloon Camera2 Hot Iron Target Unpolarized")
# Out:
# Text(0.5, 1.0, 'Balloon Camera2 Hot Iron Target Unpolarized')

# %%
img1 = np.zeros([1,256,320])

with h5py.File('C://Users//khart//Documents//Summer2022Campaign//Troubleshooting//useful//P3//hot_iron_polarized45_Camera1.h5', "r") as f:

    img1 = np.array(f[list(f.keys())[0]])
plt.imshow(img1[0])
plt.colorbar()
plt.clim(23700,24100)
plt.title("P3 Camera1 Hot Soldering Iron 45deg Polarized")
# Out:
# Text(0.5, 1.0, 'P3 Camera1 Hot Soldering Iron 45deg Polarized')

# %%
img2 = np.zeros([1,256,320])

with h5py.File('C://Users//khart//Documents//Summer2022Campaign//Troubleshooting//useful//P3//hot_iron_polarized45_Camera2.h5', "r") as f:

    img2 = np.array(f[list(f.keys())[0]])

plt.imshow(img2[0])
plt.clim(23700,24100)
plt.colorbar()
plt.title("P3 Camera2 Hot Soldering Iron 45deg Polarized")
# Out:
# Text(0.5, 1.0, 'P3 Camera2 Hot Soldering Iron 45deg Polarized')

# %%
img1[0,125,150] - img2[0,125,175]
# Out:
# 107.0

# %%
img1= np.zeros([1,256,320])

with h5py.File('C://Users//khart//Documents//Summer2022Campaign//Troubleshooting//useful//P3//hot_iron_polarized135_Camera1.h5', "r") as f:

    img1 = np.array(f[list(f.keys())[0]])

plt.imshow(img1[0])
plt.colorbar()
plt.title("P3 Camera1 Hot Soldering Iron 135deg Polarized")
plt.clim(23700,24100)

# %%
img2 = np.zeros([1,256,320])

with h5py.File('C://Users//khart//Documents//Summer2022Campaign//Troubleshooting//useful//P3//hot_iron_polarized135_Camera2.h5', "r") as f:

    img2 = np.array(f[list(f.keys())[0]])

plt.imshow(img2[0])
plt.colorbar()
plt.title("P3 Camera2 Hot Soldering Iron 135deg Polarized")
plt.clim(23700,24100)

# %%
img1 = np.zeros([1,256,320])

with h5py.File('C://Users//khart//Documents//Summer2022Campaign//Troubleshooting//useful//P3//hot_iron_unpolarized_Camera1.h5', "r") as f:

    img1 = np.array(f[list(f.keys())[0]])

plt.imshow(img1[0])
plt.colorbar()
plt.title("P3 Camera1 Hot Iron Target Unpolarized")
plt.clim(23700,24500)

# %%
img2 = np.zeros([1,256,320])

with h5py.File('C://Users//khart//Documents//Summer2022Campaign//Troubleshooting//useful//P3//hot_iron_unpolarized_Camera2.h5', "r") as f:

    img2 = np.array(f[list(f.keys())[0]])

plt.imshow(img2[0])
plt.colorbar()
plt.title("P3 Camera2 Hot Iron Target Unpolarized")
plt.clim(23700,24500)

# %%
img1[0,125,150] - img2[0,125,175]
# Out:
# 122.0

# %% [markdown]
# ## After Balloon Failure ##

# %%
angles = [0,45,90,135,180,225,270,315]
numangles = len(angles)
img1 = np.zeros([numangles,1,256,320])
img2 = np.zeros([numangles,1,256,320])


for i in range(numangles):
    with h5py.File('C://Users//khart//Documents//Summer2022Campaign//IRCSP1//Modulation_Test//65C_BBtemp//' + str(angles[i]) + 'deg.h5', "r") as f:
        print(f.keys())
        
        img1[i] = np.array(f[list(f.keys())[0]])
        img2[i] = np.array(f[list(f.keys())[1]])
# Out:
# <KeysViewHDF5 ['imgs1', 'imgs2', 'standev1', 'standev2', 'temps1', 'temps2']>
# <KeysViewHDF5 ['imgs1', 'imgs2', 'standev1', 'standev2', 'temps1', 'temps2']>
# <KeysViewHDF5 ['imgs1', 'imgs2', 'standev1', 'standev2', 'temps1', 'temps2']>
# <KeysViewHDF5 ['imgs1', 'imgs2', 'standev1', 'standev2', 'temps1', 'temps2']>
# <KeysViewHDF5 ['imgs1', 'imgs2', 'standev1', 'standev2', 'temps1', 'temps2']>
# <KeysViewHDF5 ['imgs1', 'imgs2', 'standev1', 'standev2', 'temps1', 'temps2']>
# <KeysViewHDF5 ['imgs1', 'imgs2', 'standev1', 'standev2', 'temps1', 'temps2']>
# <KeysViewHDF5 ['imgs1', 'imgs2', 'standev1', 'standev2', 'temps1', 'temps2']>

# %%
im1 = np.mean(img1,axis=1)
im2 = np.mean(img2,axis=1)

# %%
plt.imshow(im1[0,75:155,90:190])
plt.colorbar()
plt.title(str("Camera 1: Polarizer at "+ str(angles[0]) + str('deg')))
#plt.clim(24000,24100)
plt.show()
plt.imshow(im1[2,75:155,90:190])
plt.colorbar()
#plt.clim(24000,24100)
plt.title(str("Camera 1: Polarizer at "+ str(angles[2]) + str('deg')))
plt.show()

# %%
plt.imshow(im2[0,85:165,90:190])
plt.colorbar()
plt.title(str("Camera 2: Polarizer at "+ str(angles[0]) + str('deg')))
#plt.clim(23500,23640)
plt.show()
plt.imshow(im2[2,85:165,90:190])
plt.colorbar()
#plt.clim(23500,23640)
plt.title(str("Camera 2: Polarizer at "+ str(angles[2]) + str('deg')))
plt.show()

# %% [markdown]
# ## Pre-Flight ##

# %%
angles = [0,45,90,135,180,225,270,315]
numangles = len(angles)
img1 = np.zeros([numangles,1,256,320])
img2 = np.zeros([numangles,1,256,320])


for i in range(numangles):
    with h5py.File('C://Users//khart//Documents//Summer2022Campaign//IRCSP1//Calibration//8.1.2022//Polarized_BB//65C//' + str(angles[i]) + 'deg.h5', "r") as f:
        print(f.keys())
        
        img1[i] = np.array(f[list(f.keys())[1]])
        img2[i] = np.array(f[list(f.keys())[2]])
# Out:
# <KeysViewHDF5 ['Housing temp', 'imgs1', 'imgs2', 'standev1', 'standev2', 'temps1', 'temps2']>
# <KeysViewHDF5 ['Housing temp', 'imgs1', 'imgs2', 'standev1', 'standev2', 'temps1', 'temps2']>
# <KeysViewHDF5 ['Housing temp', 'imgs1', 'imgs2', 'standev1', 'standev2', 'temps1', 'temps2']>
# <KeysViewHDF5 ['Housing temp', 'imgs1', 'imgs2', 'standev1', 'standev2', 'temps1', 'temps2']>
# <KeysViewHDF5 ['Housing temp', 'imgs1', 'imgs2', 'standev1', 'standev2', 'temps1', 'temps2']>
# <KeysViewHDF5 ['Housing temp', 'imgs1', 'imgs2', 'standev1', 'standev2', 'temps1', 'temps2']>
# <KeysViewHDF5 ['Housing temp', 'imgs1', 'imgs2', 'standev1', 'standev2', 'temps1', 'temps2']>
# <KeysViewHDF5 ['Housing temp', 'imgs1', 'imgs2', 'standev1', 'standev2', 'temps1', 'temps2']>

# %%
im1 = np.mean(img1,axis=1)
im2 = np.mean(img2,axis=1)

# %%
i =0
plt.imshow(im1[i,75:155,90:190])
plt.colorbar()
plt.title(str("Camera 1: Polarizer at "+ str(angles[i]) + str('deg')))
plt.clim(23340,23500)
plt.show()
plt.imshow(im1[2,75:155,90:190])
plt.colorbar()
plt.clim(23340,23500)
plt.title(str("Camera 1: Polarizer at "+ str(angles[i+2]) + str('deg')))
plt.show()

# %%
plt.imshow(im2[0,85:165,90:190])
plt.colorbar()
plt.title(str("Camera 2: Polarizer at "+ str(angles[0]) + str('deg')))
plt.clim(22630,22470)
plt.show()
plt.imshow(im2[2,85:165,90:190])
plt.colorbar()
plt.clim(22630,22470)
plt.title(str("Camera 2: Polarizer at "+ str(angles[2]) + str('deg')))
plt.show()
